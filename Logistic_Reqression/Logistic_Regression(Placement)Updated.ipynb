# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('\\ML\\Logistic_Reqression\\placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
#  Steps
#
# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 81   5.4  107.0
# 27   6.0  124.0
# 15   5.1  176.0
# 88   4.4  149.0
# 16   5.2  224.0
# ..   ...    ...
# 14   6.1  103.0
# 46   5.3  114.0
# 45   6.0   66.0
# 56   6.1   65.0
# 60   6.9  139.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 81    0
# 27    1
# 15    0
# 88    0
# 16    0
#      ..
# 14    0
# 46    0
# 45    1
# 56    0
# 60    1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 51   4.8  141.0
# 2    5.3  121.0
# 37   8.1  149.0
# 62   6.0  102.0
# 86   5.1  128.0
# 29   7.0  112.0
# 53   8.3  168.0
# 97   6.7  182.0
# 44   7.5   61.0
# 90   7.3   86.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.47007522, -0.40820108],
#        [ 0.0700112 ,  0.01436161],
#        [-0.74011843,  1.3069063 ],
#        [-1.37021925,  0.63577732],
#        [-0.65010402,  2.50002447],
#        [-0.74011843, -1.42732285],
#        [ 1.24019845,  0.33749778],
#        [ 2.32037129, -0.08506491],
#        [ 0.97015524,  0.38721104],
#        [ 0.97015524,  1.28204967],
#        [-0.83013283, -0.13477816],
#        [-0.1100176 ,  0.46178092],
#        [-0.0200032 , -0.43305771],
#        [ 1.42022725,  0.85948698],
#        [-1.10017604, -1.77531565],
#        [-0.92014724,  0.68549058],
#        [ 1.51024166, -0.85562039],
#        [ 0.88014083,  0.36235441],
#        [ 1.24019845, -0.18449142],
#        [ 0.61009762,  0.36235441],
#        [ 0.16002561,  0.80977372],
#        [ 0.79012643, -0.28391794],
#        [-0.1100176 ,  1.05834001],
#        [-0.65010402,  0.93405687],
#        [ 0.88014083, -0.68162399],
#        [ 1.69027046, -0.23420468],
#        [-0.20003201,  0.48663755],
#        [ 0.52008322, -0.83076377],
#        [-0.92014724, -1.551606  ],
#        [-0.47007522,  0.38721104],
#        [-0.47007522,  0.28778452],
#        [ 0.52008322,  0.16350138],
#        [-0.65010402, -0.33363119],
#        [ 1.06016964,  0.68549058],
#        [-1.01016164,  1.1329099 ],
#        [-0.92014724, -0.08506491],
#        [ 0.0700112 , -1.94931205],
#        [-0.92014724,  1.80403887],
#        [-0.47007522, -0.23420468],
#        [ 1.33021285,  0.21321464],
#        [ 0.34005441,  0.08893149],
#        [-0.20003201,  0.41206767],
#        [ 0.43006882, -0.18449142],
#        [ 0.16002561,  0.21321464],
#        [-1.10017604, -0.06020828],
#        [-2.18034888,  2.72373413],
#        [-1.73027687, -0.58219748],
#        [-0.20003201,  1.1329099 ],
#        [ 0.79012643, -0.01049502],
#        [ 0.52008322, -2.14816508],
#        [ 0.34005441, -0.50762759],
#        [ 1.06016964, -1.87474217],
#        [ 0.52008322,  0.90920024],
#        [-1.19019045,  0.56120744],
#        [ 0.79012643, -0.83076377],
#        [-0.20003201,  0.21321464],
#        [ 0.0700112 ,  0.63577732],
#        [-1.37021925, -2.02388194],
#        [ 1.87029927, -1.10418668],
#        [-0.83013283, -1.50189274],
#        [ 1.96031368,  1.05834001],
#        [ 0.97015524, -1.47703611],
#        [ 0.34005441,  0.11378812],
#        [ 1.42022725,  0.16350138],
#        [ 0.16002561, -1.05447342],
#        [-1.10017604, -0.90533365],
#        [ 0.25004001, -0.25906131],
#        [ 0.70011203,  0.76006047],
#        [-0.83013283, -0.80590714],
#        [-1.82029127, -0.35848782],
#        [-0.92014724,  0.78491709],
#        [ 0.79012643,  0.43692429],
#        [ 0.97015524,  1.87860875],
#        [ 1.24019845, -1.82502891],
#        [-1.73027687, -1.20361319],
#        [-1.01016164,  0.98377012],
#        [-1.01016164, -0.28391794],
#        [ 0.61009762, -0.08506491],
#        [ 1.51024166,  0.11378812],
#        [-2.36037769,  1.4809027 ],
#        [ 0.43006882,  0.43692429],
#        [-0.65010402,  0.21321464],
#        [-0.65010402, -0.83076377],
#        [-1.46023366,  1.90346538],
#        [-0.92014724,  0.26292789],
#        [ 0.16002561, -0.50762759],
#        [-0.56008962, -0.23420468],
#        [ 0.0700112 , -1.42732285],
#        [ 0.16002561, -1.45217948],
#        [ 0.88014083,  0.38721104]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.01016164,  0.43692429],
#        [-0.56008962, -0.06020828],
#        [ 1.96031368,  0.63577732],
#        [ 0.0700112 , -0.53248422],
#        [-0.74011843,  0.11378812],
#        [ 0.97015524, -0.28391794],
#        [ 2.14034248,  1.10805327],
#        [ 0.70011203,  1.45604607],
#        [ 1.42022725, -1.551606  ],
#        [ 1.24019845, -0.93019028]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 51    0
# 2     0
# 37    1
# 62    0
# 86    0
# 29    1
# 53    1
# 97    1
# 44    1
# 90    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
